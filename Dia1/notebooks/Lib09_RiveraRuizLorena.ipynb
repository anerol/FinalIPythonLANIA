# %%
# %run ../talktools.py
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Nixie+One' rel='stylesheet' type='text/css'>
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# #notebook_panel { /* main background */
#     background: rgb(245,245,245);
# }
#
# div.cell { /* set cell width */
#     width: 750px;
# }
#
# div #notebook { /* centre the content */
#     background: #fff; /* white background for content */
#     width: 1000px;
#     margin: auto;
#     padding-left: 0em;
# }
#
# #notebook li { /* More space between bullet points */
# margin-top:0.8em;
# }
#
# /* draw border around running cells */
# div.cell.border-box-sizing.code_cell.running {
#     border: 1px solid #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them*/
# div.cell.code_cell {
#     background-color: rgb(256,256,256);
#     border-radius: 0px;
#     padding: 0.5em;
#     margin-left:1em;
#     margin-top: 1em;
# }
#
# div.text_cell_render{
#     font-family: 'Alegreya Sans' sans-serif;
#     line-height: 140%;
#     font-size: 125%;
#     font-weight: 400;
#     width:600px;
#     margin-left:auto;
#     margin-right:auto;
# }
#
#
# /* Formatting for header cells */
# .text_cell_render h1 {
#     font-family: 'Nixie One', serif;
#     font-style:regular;
#     font-weight: 400;
#     font-size: 45pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.5em;
#     margin-top: 0.5em;
#     display: block;
# }
# .text_cell_render h2 {
#     font-family: 'Nixie One', serif;
#     font-weight: 400;
#     font-size: 30pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.1em;
#     margin-top: 0.3em;
#     display: block;
# }
#
# .text_cell_render h3 {
#     font-family: 'Nixie One', serif;
#     margin-top:16px;
# 	font-size: 22pt;
#     font-weight: 600;
#     margin-bottom: 3px;
#     font-style: regular;
#     color: rgb(102,102,0);
# }
#
# .text_cell_render h4 {    /*Use this for captions*/
#     font-family: 'Nixie One', serif;
#     font-size: 14pt;
#     text-align: center;
#     margin-top: 0em;
#     margin-bottom: 2em;
#     font-style: regular;
# }
#
# .text_cell_render h5 {  /*Use this for small titles*/
#     font-family: 'Nixie One', sans-serif;
#     font-weight: 400;
#     font-size: 16pt;
#     color: rgb(163,0,0);
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.8em;
#     display: block;
# }
#
# .text_cell_render h6 { /*use this for copyright note*/
#     font-family: 'PT Mono', sans-serif;
#     font-weight: 300;
#     font-size: 9pt;
#     line-height: 100%;
#     color: grey;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .CodeMirror{
#         font-family: "PT Mono";
#         font-size: 90%;
# }
#
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"],
#                            equationNumbers: { autoNumber: "AMS", useLabelIds: true}
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %%
import pandas as pd
# %matplotlib inline

# %%
archivo = '../files/VR24_10M.xls'
pd.read_excel(archivo).head()
# Out:
#              Estación:   XALAPAob       VER  Unnamed: 3  Unnamed: 4  \
# 0         Operada por:  SMN ESIME       NaN         NaN         NaN
# 1            Longitud:  96°54'14"  Latitud:    19°30'43    Altitud:
# 2                  NaN        NaN       NaN         NaN         NaN
# 3                FECHA       DIRS      DIRR  RAPVIENTO2  RAPRAFAGA2
# 4  2014-11-03 20:00:00        269        34        1.90        5.10
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0        NaN        NaN        NaN        NaN        NaN
# 1       1360        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN
# 3       TEMP         HR         PB       PREC    RAD-SOL
# 4       20.9         62      869.5        0.0      764.0

# %%
pd.read_excel(archivo, header=4).head()
# Out:
#                 FECHA  DIRS  DIRR  RAPVIENTO2  RAPRAFAGA2  TEMP  HR     PB  \
# 0 2014-11-03 20:00:00   269    34         1.9         5.1  20.9  62  869.5
# 1 2014-11-03 20:10:00   218   355         1.3         3.2  21.5  55  869.4
# 2 2014-11-03 20:20:00   208    43         1.4         4.4  21.3  58  869.4
# 3 2014-11-03 20:30:00   199   321         1.8         4.8  20.9  58  869.3
# 4 2014-11-03 20:40:00   217   314         2.0         5.0  21.5  54  869.3
#
#    PREC  RAD-SOL
# 0     0      764
# 1     0      746
# 2     0      733
# 3     0      702
# 4     0      667

# %%
pd.read_excel(archivo, header=4, index_col='FECHA').head()
# Out:
#                      DIRS  DIRR  RAPVIENTO2  RAPRAFAGA2  TEMP  HR     PB  \
# FECHA
# 2014-11-03 20:00:00   269    34         1.9         5.1  20.9  62  869.5
# 2014-11-03 20:10:00   218   355         1.3         3.2  21.5  55  869.4
# 2014-11-03 20:20:00   208    43         1.4         4.4  21.3  58  869.4
# 2014-11-03 20:30:00   199   321         1.8         4.8  20.9  58  869.3
# 2014-11-03 20:40:00   217   314         2.0         5.0  21.5  54  869.3
#
#                      PREC  RAD-SOL
# FECHA
# 2014-11-03 20:00:00     0      764
# 2014-11-03 20:10:00     0      746
# 2014-11-03 20:20:00     0      733
# 2014-11-03 20:30:00     0      702
# 2014-11-03 20:40:00     0      667

# %%
xalapaOb =pd.read_excel(archivo, header=4, index_col='FECHA', parse_dates=True, encoding='utf-8')
xalapaOb.head()
# Out:
#                      DIRS  DIRR  RAPVIENTO2  RAPRAFAGA2  TEMP  HR     PB  \
# FECHA
# 2014-11-03 20:00:00   269    34         1.9         5.1  20.9  62  869.5
# 2014-11-03 20:10:00   218   355         1.3         3.2  21.5  55  869.4
# 2014-11-03 20:20:00   208    43         1.4         4.4  21.3  58  869.4
# 2014-11-03 20:30:00   199   321         1.8         4.8  20.9  58  869.3
# 2014-11-03 20:40:00   217   314         2.0         5.0  21.5  54  869.3
#
#                      PREC  RAD-SOL
# FECHA
# 2014-11-03 20:00:00     0      764
# 2014-11-03 20:10:00     0      746
# 2014-11-03 20:20:00     0      733
# 2014-11-03 20:30:00     0      702
# 2014-11-03 20:40:00     0      667

# %%
xalapaOb.columns
# Out:
# Index([u'DIRS', u'DIRR', u'RAPVIENTO2', u'RAPRAFAGA2', u'TEMP', u'HR', u'PB', u'PREC', u'RAD-SOL'], dtype='object')

# %%
xalapaOb.columns[0]
# Out:
# u'DIRS'

# %%
xalapaOb.columns[0].strip()
# Out:
# u'DIRS'

# %%
xalapaOb[[u'DIRS']].head()
# Out:
#                      DIRS
# FECHA
# 2014-11-03 20:00:00   269
# 2014-11-03 20:10:00   218
# 2014-11-03 20:20:00   208
# 2014-11-03 20:30:00   199
# 2014-11-03 20:40:00   217

# %%
xalapaOb[[u'TEMP']].head()
# Out:
#                      TEMP
# FECHA
# 2014-11-03 20:00:00  20.9
# 2014-11-03 20:10:00  21.5
# 2014-11-03 22:00:00  20.6
# 2014-11-03 22:10:00  20.6
# 2014-11-03 22:20:00  19.8
# 2014-11-03 22:30:00  18.7
# 2014-11-03 22:40:00  17.7
# 2014-11-03 22:50:00  17.0
# 2014-11-03 23:00:00  16.9
# 2014-11-03 23:10:00  16.6
# 2014-11-03 23:20:00  16.4
# 2014-11-03 23:30:00  16.1
# 2014-11-03 23:40:00  15.7
# 2014-11-03 23:50:00  15.6
# 2014-11-04 00:00:00  15.6
# 2014-11-04 00:10:00  15.5
# 2014-11-04 00:20:00  15.4
# 2014-11-04 00:30:00  15.4
# 2014-11-04 00:40:00  15.4
# 2014-11-04 00:50:00  15.4
# ...                   ...
# 2014-11-04 14:50:00  16.4
# 2014-11-04 15:00:00  16.4
# 2014-11-04 15:10:00  16.5
# 2014-11-04 15:20:00  17.8
# 2014-11-04 15:30:00  16.9
# 2014-11-04 15:40:00  17.7
# 2014-11-04 15:50:00  17.2
# 2014-11-04 16:00:00  17.4
# 2014-11-04 16:10:00  18.1
# 2014-11-04 16:20:00  18.2
# 2014-11-04 16:30:00  17.3
# 2014-11-04 16:40:00  18.1
# 2014-11-04 16:50:00  18.7
# 2014-11-04 17:00:00  17.8
# 2014-11-04 17:10:00  18.3
# 2014-11-04 17:20:00  18.6
# 2014-11-04 17:30:00  18.6
# 2014-11-04 17:40:00  19.1
# 2014-11-04 17:50:00  18.4
# 2014-11-04 18:00:00  18.9
# 2014-11-04 18:10:00  18.8
# 2014-11-04 18:20:00  18.7
# 2014-11-04 18:30:00  20.0
# 2014-11-04 18:40:00  20.0
# 2014-11-04 18:50:00  20.8
# 2014-11-04 19:00:00  21.5
# 2014-11-04 19:10:00  21.9
# 2014-11-04 19:20:00  20.8
# 2014-11-04 19:30:00  20.4
# 2014-11-04 19:40:00  20.2
#
# [143 rows x 1 columns]

# %%
CustomPlot()
xalapaOb.plot()

# %%
xalapaOb.median()
# Out:
# DIRS          174.0
# DIRR          266.0
# RAPVIENTO2      1.3
# RAPRAFAGA2      2.9
# TEMP           14.8
# HR             99.0
# PB            869.1
# PREC            0.0
# RADSOL          0.0
# dtype: float64

# %%
xalapaOb.mean()
# Out:
# DIRS          185.727273
# DIRR          250.083916
# RAPVIENTO2      1.394406
# RAPRAFAGA2      3.051049
# TEMP           15.770629
# HR             86.853147
# PB            869.281818
# PREC            0.006993
# RADSOL        176.041958
# dtype: float64

# %%
xalapaOb.mean().plot(kind='bar')

# %%
figsize(11.5, 6)
font_size = 20
plt.title('Temperatura en Xalapa (24 horas)',fontsize = font_size)
plt.xlabel('hora',fontsize = font_size)
plt.ylabel(r'Temperatura [$^\circ C$] ',fontsize = font_size)
xalapaOb['TEMP'].plot();

# %%
figsize(11.5, 6)
font_size = 20
plt.title('Temperatura en Xalapa (24 horas)',fontsize = font_size)
plt.xlabel('hora',fontsize = font_size)
plt.ylabel(r'Temperatura [$^\circ C$] ',fontsize = font_size)
xalapaOb.TEMP.plot();

# %%
figsize(11.5, 6)
font_size = 20
plt.title( 'Radiacion solar', fontsize=font_size)
plt.xlabel('horac', fontsize = font_size)
plt.ylabel(r'$MJ / day / m^2$',fontsize = font_size)
xalapaOb.RADSOL.plot();

# %%
xalapaOb.index
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2014-11-03 20:00:00, ..., 2014-11-04 19:40:00]
# Length: 143, Freq: None, Timezone: None

# %%
madrugada = xalapaOb['2014-11-03 3:00:00' : '2014-11-04 6:00:00']
madrugada.TEMP.head()
# Out:
# FECHA
# 2014-11-03 20:00:00    20.9
# 2014-11-03 20:10:00    21.5
# 2014-11-03 20:20:00    21.3
# 2014-11-03 20:30:00    20.9
# 2014-11-03 20:40:00    21.5
# Name: TEMP, dtype: float64

# %%
media = xalapaOb.TEMP.mean()
media
# Out:
# 15.770629370629372

# %%
madrugada[madrugada.TEMP <= media].head()
# Out:
#                      DIRS  DIRR  RAPVIENTO2  RAPRAFAGA2  TEMP  HR     PB  \
# FECHA
# 2014-11-03 23:40:00   114   154         1.9         3.2  15.7  96  869.2
# 2014-11-03 23:50:00   117   208         1.5         3.0  15.6  97  869.2
# 2014-11-04 00:00:00   127   251         0.9         2.1  15.6  98  869.3
# 2014-11-04 00:10:00   113   242         1.2         2.6  15.5  98  869.3
# 2014-11-04 00:20:00   113   213         1.2         2.2  15.4  99  869.3
#
#                      PREC  RADSOL
# FECHA
# 2014-11-03 23:40:00     0       5
# 2014-11-03 23:50:00     0       2
# 2014-11-04 00:00:00     0       0
# 2014-11-04 00:10:00     0       0
# 2014-11-04 00:20:00     0       0

# %%
madrugada[madrugada.TEMP > media].head()
# Out:
#                      DIRS  DIRR  RAPVIENTO2  RAPRAFAGA2  TEMP  HR     PB  \
# FECHA
# 2014-11-03 20:00:00   269    34         1.9         5.1  20.9  62  869.5
# 2014-11-03 20:10:00   218   355         1.3         3.2  21.5  55  869.4
# 2014-11-03 20:20:00   208    43         1.4         4.4  21.3  58  869.4
# 2014-11-03 20:30:00   199   321         1.8         4.8  20.9  58  869.3
# 2014-11-03 20:40:00   217   314         2.0         5.0  21.5  54  869.3
#
#                      PREC  RADSOL
# FECHA
# 2014-11-03 20:00:00     0     764
# 2014-11-03 20:10:00     0     746
# 2014-11-03 20:20:00     0     733
# 2014-11-03 20:30:00     0     702
# 2014-11-03 20:40:00     0     667

# %%
xalapaOb['TEMP'].describe()
# Out:
# count    143.000000
# mean      15.770629
# std        2.983094
# min       12.000000
# 25%       13.400000
# 50%       14.800000
# 75%       17.950000
# max       22.700000
# dtype: float64

# %%
figsize(11.5, 6)
font_size = 20
plt.title('Distribucion de la rapidez del viento', fontsize=font_size)
# plt.ylabel('frecuen',fontsize = font_size)
plt.xlabel('Nudos',fontsize = font_size)
xalapaOb.RAPVIENTO2.hist(bins=6);
