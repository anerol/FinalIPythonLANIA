# %%
# %run ../talktools.py
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Nixie+One' rel='stylesheet' type='text/css'>
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# #notebook_panel { /* main background */
#     background: rgb(245,245,245);
# }
#
# div.cell { /* set cell width */
#     width: 750px;
# }
#
# div #notebook { /* centre the content */
#     background: #fff; /* white background for content */
#     width: 1000px;
#     margin: auto;
#     padding-left: 0em;
# }
#
# #notebook li { /* More space between bullet points */
# margin-top:0.8em;
# }
#
# /* draw border around running cells */
# div.cell.border-box-sizing.code_cell.running {
#     border: 1px solid #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them*/
# div.cell.code_cell {
#     background-color: rgb(256,256,256);
#     border-radius: 0px;
#     padding: 0.5em;
#     margin-left:1em;
#     margin-top: 1em;
# }
#
# div.text_cell_render{
#     font-family: 'Alegreya Sans' sans-serif;
#     line-height: 140%;
#     font-size: 125%;
#     font-weight: 400;
#     width:600px;
#     margin-left:auto;
#     margin-right:auto;
# }
#
#
# /* Formatting for header cells */
# .text_cell_render h1 {
#     font-family: 'Nixie One', serif;
#     font-style:regular;
#     font-weight: 400;
#     font-size: 45pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.5em;
#     margin-top: 0.5em;
#     display: block;
# }
# .text_cell_render h2 {
#     font-family: 'Nixie One', serif;
#     font-weight: 400;
#     font-size: 30pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.1em;
#     margin-top: 0.3em;
#     display: block;
# }
#
# .text_cell_render h3 {
#     font-family: 'Nixie One', serif;
#     margin-top:16px;
# 	font-size: 22pt;
#     font-weight: 600;
#     margin-bottom: 3px;
#     font-style: regular;
#     color: rgb(102,102,0);
# }
#
# .text_cell_render h4 {    /*Use this for captions*/
#     font-family: 'Nixie One', serif;
#     font-size: 14pt;
#     text-align: center;
#     margin-top: 0em;
#     margin-bottom: 2em;
#     font-style: regular;
# }
#
# .text_cell_render h5 {  /*Use this for small titles*/
#     font-family: 'Nixie One', sans-serif;
#     font-weight: 400;
#     font-size: 16pt;
#     color: rgb(163,0,0);
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.8em;
#     display: block;
# }
#
# .text_cell_render h6 { /*use this for copyright note*/
#     font-family: 'PT Mono', sans-serif;
#     font-weight: 300;
#     font-size: 9pt;
#     line-height: 100%;
#     color: grey;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .CodeMirror{
#         font-family: "PT Mono";
#         font-size: 90%;
# }
#
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"],
#                            equationNumbers: { autoNumber: "AMS", useLabelIds: true}
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %%
import pandas as pd
file_name = '../files/SensorRecord_20141024.csv'
sensorData = pd.read_csv(file_name)
sensorData = pd.read_csv(file_name, sep=';',header=1)
sensorData[:10]
# Out:
#    ACCELEROMETER X (m/s²)  ACCELEROMETER Y (m/s²)  ACCELEROMETER Z (m/s²)  \
# 0                  0.3172                  3.4141                  8.7843
# 1                 -0.1891                  2.2015                  8.6921
# 2                 -3.5291                  0.9697                  5.6515
# 3                -19.6127                  0.5878                  0.8092
# 4                 -9.6510                 -7.9428                  0.8763
# 5                  4.6424                 -9.1075                  1.7729
# 6                 -1.3372                -10.1586                  1.4904
# 7                 -4.7896                -15.4570                 -5.4145
# 8                  1.8711                 -3.8176                  1.5909
# 9                 -5.6611                -14.5974                 -4.6519
#
#    GRAVITY X (m/s²)  GRAVITY Y (m/s²)  GRAVITY Z (m/s²)  \
# 0            0.1504            3.2931            9.2360
# 1           -1.1530            2.7405            9.3451
# 2           -2.5132            3.0414            8.9780
# 3           -9.2648           -2.0155            2.5043
# 4           -9.5497           -2.0285            0.9264
# 5            0.6805           -9.4990           -2.3402
# 6            0.1363           -9.3628           -2.9136
# 7            0.2268           -9.7510           -1.0188
# 8            0.0988           -9.8058           -0.0847
# 9            0.8679           -8.9782            3.8483
#
#    LINEAR ACCELERATION X (m/s²)  LINEAR ACCELERATION Y (m/s²)  \
# 0                        0.1668                        0.1210
# 1                        0.9639                       -0.5390
# 2                       -1.0159                       -2.0717
# 3                      -10.3479                        2.6033
# 4                       -0.1013                       -5.9143
# 5                        3.9618                        0.3914
# 6                       -1.4735                       -0.7958
# 7                       -5.0164                       -5.7060
# 8                        1.7723                        5.9882
# 9                       -6.5289                       -5.6193
#
#    LINEAR ACCELERATION Z (m/s²)  GYROSCOPE X (rad/s)         ...           \
# 0                       -0.4516               0.0468         ...
# 1                       -0.6529               0.3147         ...
# 2                       -3.3265               0.1884         ...
# 3                       -1.6951               2.3041         ...
# 4                       -0.0501              -1.5049         ...
# 5                        4.1132               3.0478         ...
# 6                        4.4040              -0.9374         ...
# 7                       -4.3957               0.4050         ...
# 8                        1.6756              -0.1142         ...
# 9                       -8.5003               0.3006         ...
#
#    LOCATION Longitude :   LOCATION Altitude ( m)  LOCATION Speed ( Kmh)  \
# 0              -96.91544                     NaN                    NaN
# 1              -96.91544                     NaN                    NaN
# 2              -96.91544                     NaN                    NaN
# 3              -96.91544                     NaN                    NaN
# 4              -96.91544                     NaN                    NaN
# 5              -96.91544                     NaN                    NaN
# 6              -96.91544                     NaN                    NaN
# 7              -96.91544                     NaN                    NaN
# 8              -96.91544                     NaN                    NaN
# 9              -96.91544                     NaN                    NaN
#
#    LOCATION Accuracy ( m)  Satellites in range  Temperature (C)  Level (%)  \
# 0               188.70969                0 / 2             28.8         96
# 1               188.70969                0 / 4             28.8         96
# 2               188.70969                0 / 4             28.8         96
# 3               188.70969                0 / 3             28.8         96
# 4               188.70969                0 / 3             28.8         96
# 5               188.70969                0 / 3             28.8         96
# 6               188.70969                0 / 3             28.8         96
# 7               188.70969                0 / 3             28.8         96
# 8               188.70969                0 / 3             28.8         96
# 9               188.70969                0 / 3             28.8         96
#
#    Voltage (Volt)  Time since start in ms   YYYY-MO-DD HH-MI-SS_SSS
# 0           4.225                      222  2014-10-24 12:39:55:105
# 1           4.225                      805  2014-10-24 12:39:55:688
# 2           4.225                     1411  2014-10-24 12:39:56:294
# 3           4.225                     2503  2014-10-24 12:39:57:386
# 4           4.225                     3080  2014-10-24 12:39:57:963
# 5           4.225                     3780  2014-10-24 12:39:58:663
# 6           4.225                     4708  2014-10-24 12:39:59:591
# 7           4.225                     5265  2014-10-24 12:40:00:148
# 8           4.225                     5932  2014-10-24 12:40:00:815
# 9           4.225                     6496  2014-10-24 12:40:01:379
#
# [10 rows x 31 columns]

# %%
sensorData.iloc[:,0:3]
# Out:
#      ACCELEROMETER X (m/s²)  ACCELEROMETER Y (m/s²)  ACCELEROMETER Z (m/s²)
# 0                    0.3172                  3.4141                  8.7843
# 1                   -0.1891                  2.2015                  8.6921
# 2                   -3.5291                  0.9697                  5.6515
# 3                  -19.6127                  0.5878                  0.8092
# 4                   -9.6510                 -7.9428                  0.8763
# 5                    4.6424                 -9.1075                  1.7729
# 6                   -1.3372                -10.1586                  1.4904
# 7                   -4.7896                -15.4570                 -5.4145
# 8                    1.8711                 -3.8176                  1.5909
# 9                   -5.6611                -14.5974                 -4.6519
# 10                   3.3363                -19.6133                -17.4920
# 11                  -1.2617                -11.2911                  2.4768
# 12                  -1.2773                -11.5233                  7.7596
# 13                   3.0921                -12.6246                  0.0443
# 14                  -3.4381                 -7.9440                  1.2438
# 15                  -0.4262                -10.3681                  0.9960
# 16                  -2.1416                 -9.0980                  4.2018
# 17                  -3.3148                -11.5233                  3.6428
# 18                   8.4192                -14.8357                  0.8475
# 19                   0.7506                -10.1071                  0.9445
# 20                   1.8423                 -9.5409                  0.6201
# 21                   1.7645                 -9.5792                  0.4693
# 22                   0.6273                 -9.7827                 -1.4473
# 23                   3.2597                 -8.0278                 -3.9804
# 24                   2.1727                 -8.5629                  1.5131
# 25                   3.7960                 -8.9807                  0.9002
# 26                   4.5981                 -8.9651                  0.6871
# 27                   2.5594                 -9.7947                 -0.2562
# 28                  -0.0946                 -9.4188                 -0.9158
# 29                   5.7102                 -8.9352                 -3.4201
# ..                      ...                     ...                     ...
# 136                 -0.8368                 -9.9515                  0.1389
# 137                  3.1759                 -7.9667                 -1.8794
# 138                  1.7933                 -9.4248                  1.9836
# 139                  2.2805                 -9.0106                 -0.5997
# 140                  2.9137                 -8.1570                 -2.9760
# 141                 -0.3723                 -8.5940                  2.5163
# 142                  2.0387                -11.9842                  2.9269
# 143                 -1.0271                 -7.2101                  1.3970
# 144                 -0.8056                 -6.1890                  2.8443
# 145                  3.6332                -10.0161                  3.0694
# 146                  3.0179                -10.8350                  2.4768
# 147                  7.0916                -17.9649                  0.0646
# 148                 -2.7569                -12.9502                  3.4153
# 149                  7.6028                -19.6133                 -1.5778
# 150                  0.9768                -12.7228                 -0.0970
# 151                  0.9673                 -3.7074                  2.7054
# 152                 -0.4238                 -9.5457                 -6.5864
# 153                  3.6224                 -7.1587                  2.6300
# 154                  0.8392                -13.1609                  2.4146
# 155                  6.4943                 -9.4463                 -0.8056
# 156                  0.1281                 -5.2637                 -1.7274
# 157                 -6.6176                 -5.8395                 -2.9987
# 158                 -8.8178                -11.4850                  1.7801
# 159                -15.6126                  6.5170                  2.0662
# 160                 -2.5438                  3.6595                  8.7855
# 161                 -0.5495                  7.0437                  6.6499
# 162                 -2.3487                  4.9799                  7.1263
# 163                 -5.3965                  3.7697                  8.0768
# 164                 -2.7078                  5.4600                  8.2361
# 165                 -2.1596                  7.3969                  5.8694
#
# [166 rows x 3 columns]

# %%
sensorData['ACCELEROMETER X (m/s²)']
# Out:
# 0      0.3172
# 1     -0.1891
# 2     -3.5291
# 3    -19.6127
# 4     -9.6510
# 5      4.6424
# 6     -1.3372
# 7     -4.7896
# 8      1.8711
# 9     -5.6611
# 10     3.3363
# 11    -1.2617
# 12    -1.2773
# 13     3.0921
# 14    -3.4381
# ...
# 151     0.9673
# 152    -0.4238
# 153     3.6224
# 154     0.8392
# 155     6.4943
# 156     0.1281
# 157    -6.6176
# 158    -8.8178
# 159   -15.6126
# 160    -2.5438
# 161    -0.5495
# 162    -2.3487
# 163    -5.3965
# 164    -2.7078
# 165    -2.1596
# Name: ACCELEROMETER X (m/s²), Length: 166, dtype: float64

# %%
# %matplotlib inline

# %%
geodatos = sensorData.iloc[:,20:22]
geodatos[:10]
sensorData.plot(legend = False)

# %%
geodatos.plot()

# %%
geodatos.keys()
# Out:
# Index([u'LOCATION Latitude : ', u'LOCATION Longitude : '], dtype='object')

# %%
geodatos.plot(x='LOCATION Latitude : ', y='LOCATION Longitude : ', kind='scatter')

# %%
from mpl_toolkits.basemap import Basemap
from datetime import datetime

# %%
lats=geodatos.values[:,0]
lons=geodatos.values[:,1]

#timeStamp = sensorData['Timestamp']

# %%
geodatos.values
# Out:
# array([[ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ],
#        [ 19.519932, -96.91544 ]])

# %%
m = Basemap(projection='hammer', lon_0=-90)
x,y = m(lons,lats)
m.drawmapboundary(fill_color='#99ffff')
m.fillcontinents(color='#cc9966', lake_color='#99ffff')
m.scatter(x,y,24,marker='o', color='k')
plt.text(x[-1],y[-1],'LANIA', color='b')

# %%
map = Basemap(projection='mill',lon_0=-90)
# plot coastlines, draw label meridians and parallels.
map.drawcoastlines()
map.drawparallels(np.arange(-90,90,30),labels=[1,0,0,0])
map.drawmeridians(np.arange(map.lonmin,map.lonmax+30,60),labels=[0,0,0,1])
# fill continents 'coral' (with zorder=0), color wet areas 'aqua'
map.drawmapboundary(fill_color='#99ffff')
map.fillcontinents(color='coral',lake_color='#99ffff')
x, y = map(lons,lats)
map.scatter(x,y,24,marker='o', color='b')
plt.text(x[-1],y[-1],'LANIA',color='b');
date = datetime.utcnow()
#date=datetime.utcfromtimestamp(timeStamp.values[-1])
CS=map.nightshade(date)
plt.title('Day/Night Map for %s (UTC)' % date.strftime("%d %b %Y %H:%M:%S"));

# %%
sensorData.iloc[:,30:31]
# Out:
#      YYYY-MO-DD HH-MI-SS_SSS
# 0    2014-10-24 12:39:55:105
# 1    2014-10-24 12:39:55:688
# 2    2014-10-24 12:39:56:294
# 3    2014-10-24 12:39:57:386
# 4    2014-10-24 12:39:57:963
# 5    2014-10-24 12:39:58:663
# 6    2014-10-24 12:39:59:591
# 7    2014-10-24 12:40:00:148
# 8    2014-10-24 12:40:00:815
# 9    2014-10-24 12:40:01:379
# 10   2014-10-24 12:40:02:082
# 11   2014-10-24 12:40:02:634
# 12   2014-10-24 12:40:03:216
# 13   2014-10-24 12:40:03:805
# 14   2014-10-24 12:40:04:334
# 15   2014-10-24 12:40:04:904
# 16   2014-10-24 12:40:05:425
# 17   2014-10-24 12:40:05:966
# 18   2014-10-24 12:40:06:627
# 19   2014-10-24 12:40:07:257
# 20   2014-10-24 12:40:07:768
# 21   2014-10-24 12:40:08:277
# 22   2014-10-24 12:40:08:853
# 23   2014-10-24 12:40:09:458
# 24   2014-10-24 12:40:09:999
# 25   2014-10-24 12:40:10:573
# 26   2014-10-24 12:40:11:092
# 27   2014-10-24 12:40:11:688
# 28   2014-10-24 12:40:12:312
# 29   2014-10-24 12:40:12:904
# ..                       ...
# 136  2014-10-24 12:41:13:182
# 137  2014-10-24 12:41:13:703
# 138  2014-10-24 12:41:14:217
# 139  2014-10-24 12:41:14:717
# 140  2014-10-24 12:41:15:292
# 141  2014-10-24 12:41:15:814
# 142  2014-10-24 12:41:16:561
# 143  2014-10-24 12:41:17:116
# 144  2014-10-24 12:41:17:656
# 145  2014-10-24 12:41:18:175
# 146  2014-10-24 12:41:18:683
# 147  2014-10-24 12:41:19:227
# 148  2014-10-24 12:41:19:767
# 149  2014-10-24 12:41:20:279
# 150  2014-10-24 12:41:20:782
# 151  2014-10-24 12:41:21:282
# 152  2014-10-24 12:41:21:782
# 153  2014-10-24 12:41:22:287
# 154  2014-10-24 12:41:22:803
# 155  2014-10-24 12:41:23:324
# 156  2014-10-24 12:41:23:842
# 157  2014-10-24 12:41:24:351
# 158  2014-10-24 12:41:24:854
# 159  2014-10-24 12:41:25:438
# 160  2014-10-24 12:41:25:955
# 161  2014-10-24 12:41:26:609
# 162  2014-10-24 12:41:27:237
# 163  2014-10-24 12:41:27:775
# 164  2014-10-24 12:41:28:364
# 165  2014-10-24 12:41:28:916
#
# [166 rows x 1 columns]

# %%
timeStamp = sensorData.iloc[:,30:31]

# %%
vFechaHoraCompleta = str(timeStamp.values[-1]).split()

# %%
vFechaHoraCompleta[0] + " | " + vFechaHoraCompleta[1]
# Out:
# "['2014-10-24 | 12:41:28:916']"

# %%
vFechaCompleta = vFechaHoraCompleta[0]
vFechaSeparada = vFechaCompleta.split("-")
vAnio = vFechaSeparada[0][-4]
vAnio += vFechaSeparada[0][-3]
vAnio += vFechaSeparada[0][-2]
vAnio += vFechaSeparada[0][-1]
iAnio = int(vAnio)
iMes  = int(vFechaSeparada[1])
iDia  = int(vFechaSeparada[2])

# %%
print str(iAnio) + " " + str(iMes) + " " + str(iDia)
# Out:
# 2014 10 24

# %%
vHoraCompleta = vFechaHoraCompleta[1]
vHoraSeparada = vHoraCompleta.split(":")
iHora = int(vHoraSeparada[0])
iMin  = int(vHoraSeparada[1])
iSeg  = int(vHoraSeparada[2])

# %%
print str(iHora) + " " + str(iMin) + " " + str(iSeg)
# Out:
# 12 41 28

# %%
vFechaRegistrada = datetime(iAnio, iMes, iDia, iHora, iMin, iSeg)

# %%
vFechaRegistrada
# Out:
# datetime.datetime(2014, 10, 24, 12, 41, 28)

# %%
from datetime import timedelta

def totimestamp(dt, epoch=datetime(1970,1,1)):
    td = dt - epoch
    # return td.total_seconds()
    return (td.microseconds + (td.seconds + td.days * 24 * 3600) * 10**6) / 1e6

# %%
vFechaRegistrada
# Out:
# datetime.datetime(2014, 10, 24, 12, 41, 28)

# %%
vFechaFloat = totimestamp(vFechaRegistrada)

# %%
vFechaFloat
# Out:
# 1414154488.0

# %%
map = Basemap(projection='mill',lon_0=-90)
# plot coastlines, draw label meridians and parallels.
map.drawcoastlines()
map.drawparallels(np.arange(-90,90,30),labels=[1,0,0,0])
map.drawmeridians(np.arange(map.lonmin,map.lonmax+30,60),labels=[0,0,0,1])
# fill continents 'coral' (with zorder=0), color wet areas 'aqua'
map.drawmapboundary(fill_color='#99ffff')
map.fillcontinents(color='coral',lake_color='#99ffff')
x, y = map(lons,lats)
map.scatter(x,y,24,marker='o', color='b')
plt.text(x[-1],y[-1],'LANIA',color='b');
# date = datetime.utcnow()
date=datetime.utcfromtimestamp(vFechaFloat)
CS=map.nightshade(date)
plt.title('Day/Night Map for %s (UTC)' % date.strftime("%d %b %Y %H:%M:%S"));

# %%
map = Basemap(projection='mill',lon_0=-90, lat_0=0,
    llcrnrlon=-120, llcrnrlat=0.0,
    urcrnrlon=-70, urcrnrlat=30.75)
# plot coastlines, draw label meridians and parallels.
map.drawcoastlines()
map.drawparallels(np.arange(map.latmin,map.latmax,10),labels=[1,1,1,1])
map.drawmeridians(np.arange(map.lonmin,map.lonmax,20),labels=[0,0,0,1])
# fill continents 'coral' (with zorder=0), color wet areas 'aqua'a
map.drawmapboundary(fill_color='#99ffff')
map.fillcontinents(color='coral',lake_color='#99ffff')
x, y = map(lons,lats)
map.plot(x, y, 'bo', markersize=18)
plt.text(x[-1],y[-1],'LANIA');

# %%
map = Basemap(lon_0=-90,lat_0=-0,
    llcrnrlon=-98, llcrnrlat=18.0,
    urcrnrlon=-96, urcrnrlat=20,
    resolution='l',area_thresh=0.01,projection='merc')
# plot coastlines, draw label meridians and parallels.
map.drawcoastlines()
map.drawstates()
# map.drawparallels(np.arange(map.latmin,map.latmax,40),labels=[1,1,1,1])
# map.drawmeridians(np.arange(map.lonmin,map.lonmax,40),labels=[0,0,0,1])
# fill continents 'coral' (with zorder=0), color wet areas 'aqua'a
map.drawmapboundary(fill_color='#99ffff')
map.fillcontinents(color='coral',lake_color='#99ffff')
x, y = map(lons,lats)
map.plot(x, y, 'bo', markersize=18)
map.bluemarble()
plt.text(x[-1],y[-1],'LANIA');
